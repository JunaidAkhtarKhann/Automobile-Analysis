# %% [markdown]
# <a href="https://colab.research.google.com/github/JunaidAkhtarKhann/Automobile-Analysis/blob/main/Data_Preprocessing_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Write a Python program to create a Pie plot to get the frequency of the three species of the Iris data (Use iris.csv).

# %%
# Importing iris.csv file from Seaborn Lib..
import seaborn as sns

# %%
x = sns.load_dataset('iris')
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Creating Pyplot chart by importing matplotlib.pyplot lib..
import matplotlib.pyplot as plt

# %%
# Counting Species from the iris dataset
species_count = x['species'].value_counts()
species_count
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5, 5))
plt.pie(species_count, labels=species_count.index, autopct='%1.1f%%', colors=['gold', 'lightcoral', 'yellowgreen'], startangle=140, shadow=True)
plt.title('Frequency of Iris Species')
plt.axis('equal')
# Out:
# (-1.0999980439720662,
#  1.0999980439735042,
#  -1.0999980439728572,
#  1.0999980439742956)

# %% [markdown]
# # Write a Python program to view basic statistical details of the data. (Use wineequality-red.csv)

# %%
# Importing wineequality-re.csv file using pandas lib.
import pandas as pd

# %%
# veiwing the basic statistical values using describe() function inside pandas
x1 = pd.read_csv('/content/winequalityN.csv')
x1.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# # Write a Python program for Handling Missing Value. Replace missing value of salary, age column with mean of that column. (Use Data.csv file).

# %% [markdown]
# # Write a Python program to generate a line plot of name Vs salary

# %% [markdown]
# # Write a Python program to create box plots to see how each feature i.e. Sepal Length, Sepal Width, Petal Length, Petal Width are distributed across the three species. (Use iris.csv dataset)

# %%
print(x.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Set the plot style
sns.set(style="whitegrid")


# Create a figure with subplots for each feature
plt.figure(figsize=(12, 8))

# Create a box plot for Sepal Length
plt.subplot(2, 2, 1)
sns.boxplot(x='species', y='sepal_length', data=x)
plt.title('Sepal Length Distribution by Species')

# Create a box plot for Sepal Width
plt.subplot(2, 2, 2)
sns.boxplot(x='species', y='sepal_width', data=x)
plt.title('Sepal Width Distribution by Species')

# Create a box plot for Petal Length
plt.subplot(2, 2, 3)
sns.boxplot(x='species', y='petal_length', data=x)
plt.title('Petal Length Distribution by Species')

# Create a box plot for Petal Width
plt.subplot(2, 2, 4)
sns.boxplot(x='species', y='petal_width', data=x)
plt.title('Petal Width Distribution by Species')
# Out:
# Text(0.5, 1.0, 'Petal Width Distribution by Species')

# %%
# Adjust the layout and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Write a Python program to view basic statistical details of the data (Use Heights and Weights Dataset)

# %%
print(x)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
x.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Generate a random array of 50 integers and display them using a line chart, scatter plot, histogram and box plot. Apply appropriate color, labels and styling options.

# %%
# Import the numpy Library to generate array
import numpy as np

# %%
# Generate a random array of 50 integers between 1 and 100
data = np.random.randint(1,101, size = 50)

# %%
# set the plot style
plt.style.use('seaborn-darkgrid')
# Out:
# <ipython-input-22-a668e7e00a39>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
# Create the figure for multiple subplots
plt.figure(figsize=(12, 10))

# %%
# 1. Line chart
plt.subplot(2, 2, 1)
plt.plot(data, color='b', marker='o', linestyle='-', linewidth=2, markersize=6)
plt.title('Line Chart', fontsize=14)
plt.xlabel('Index', fontsize=12)
plt.ylabel('Value', fontsize=12)
# Out:
# Text(0, 0.5, 'Value')

# %%
# 2. Scatter plot
plt.subplot(2, 2, 2)
plt.scatter(range(len(data)), data, color='r', marker='D', s=80, edgecolors='black')
plt.title('Scatter Plot', fontsize=14)
plt.xlabel('Index', fontsize=12)
plt.ylabel('Value', fontsize=12)
# Out:
# Text(0, 0.5, 'Value')

# %%
# 3. Histogram
plt.subplot(2, 2, 3)
plt.hist(data, bins=10, color='g', edgecolor='black')
plt.title('Histogram', fontsize=14)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# 4. Box plot
plt.subplot(2, 2, 4)
plt.boxplot(data, patch_artist=True, boxprops=dict(facecolor='cyan', color='blue'),
            whiskerprops=dict(color='blue'), capprops=dict(color='blue'), medianprops=dict(color='red'))
plt.title('Box Plot', fontsize=14)
plt.ylabel('Value', fontsize=12)
# Out:
# Text(0, 0.5, 'Value')

# %%
# Adjust the layout and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Write a Python program to print the shape, number of rows-columns, data types, feature names and the description of the data (Use User_Data.csv)

# %%
# import the User_Data from the path
a2 = pd.read_csv('/content/User_Data.csv')
a2
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
# Getting the shape,shape, number of rows and columns, data types, feature names, and description of the data of data using pandas lib
import pandas as pd

# %%
# shape()
print("Shape of the Dataset Rows, Columns : " ,a2.shape)
# Out:
# Shape of the Dataset Rows, Columns :  (400, 5)

# %%
# Print the number of rows and columns
print("Number of rows:", a2.shape[0])
print("Number of columns:", a2.shape[1])
# Out:
# Number of rows: 400
# Number of columns: 5

# %%
# Print the data types of each column
print("\nData types of each feature:")
print(a2.dtypes)
# Out:
# Data types of each feature:
# User ID             int64
# Gender             object
# Age                 int64
# EstimatedSalary     int64
# Purchased           int64
# dtype: object

# %%
# Print the feature (column) names
print("\nFeature names:")
print(a2.columns.tolist())
# Out:
# Feature names:
# ['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased']

# %%
# Print the statistical description of the dataset
print("\nStatistical description of the dataset:")
print(a2.describe())
# Out:
# Statistical description of the dataset:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %% [markdown]
# # Write a Python program for Handling Missing Value. Replace missing value of salary, age column with mean of that column. (Use Data.csv file).

# %%
# Importing the file
a3 = pd.read_csv("/content/User_Data_Null.csv")
a3
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
# Checking the Null Values
a3.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                6
# EstimatedSalary    7
# Purchased          0
# dtype: int64

# %%
# Checking the Mean value for salary and Age column
Age_mean = a3['Age'].mean()
Salary_mean = a3['EstimatedSalary'].mean()
print(f'Mean of Age : {Age_mean}')
print(f' Mean of Salary : {Salary_mean}')
# Out:
# Mean of Age : 37.7741116751269
#  Mean of Salary : 70292.62086513995

# %%
# Filling the missing value of age column
a3['Age'].fillna(Age_mean, inplace=True)

# %%
# Filling the missing values of Salary Column
a3['EstimatedSalary'].fillna(Salary_mean, inplace = True)

# %%
# Checking the Data again to find is there ay missing values or not
a3.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [markdown]
# # Write a Python program to generate a line plot of name Vs salary.

# %%
# Importing the file
a4 = pd.read_excel('/content/Employees.xlsx')
a4.head()
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 0   1     Ghadir     Hmshw    Male 2018-04-04      2     Quality Control
# 1   2       Omar    Hishan    Male 2020-05-21      0     Quality Control
# 2   3      Ailya    Sharaf  Female 2017-09-28      3  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male 2018-08-14      2       Manufacturing
# 4   5      Ahmad     Bikri    Male 2020-03-11      0       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            1              0             183
# ...

# %%
# Printing the column details
print(a4.columns, end = ' ')
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Annual Salary',
#        'Job Rate', 'Sick Leaves', 'Unpaid Leaves', 'Overtime Hours'],
#       dtype='object')

# %%
# Checking the Datatype of name and salary column
print(a4['Annual Salary'].dtypes)
print(a4['First Name'].dtypes)
# Out:
# int64
# object

# %%
# Plotting the line plot for Name vs Salary
plt.plot(a4['First Name'], a4['Annual Salary'], marker = 'o', linestyle = '-', color = 'b')
# Adding labels and title
plt.xlabel('FirstName')
plt.ylabel('Salary')
plt.title('Line Plot: Name vs Salary')
# Out:
# Text(0.5, 1.0, 'Line Plot: Name vs Salary')

# %% [markdown]
# # 1) Write a Python program to perform the following tasks :
# a. Apply OneHot coding on Country column.
# B. Apply Label encoding on purchased column (Data.csv have two categorical column the country column, and the purchased column).

# %%
# Istall scikit learn
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
a4.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Annual Salary',
#        'Job Rate', 'Sick Leaves', 'Unpaid Leaves', 'Overtime Hours'],
#       dtype='object')

# %%
# --- Part A: Apply OneHot Encoding on the 'Country' column ---

# Create a OneHotEncoder instance
onehotencoder = OneHotEncoder()

# Perform OneHot Encoding on the 'Country' column
# The result is a NumPy array, so convert it back to a DataFrame
encoded_country = pd.DataFrame(onehotencoder.fit_transform(a4[['Country']]).toarray(),
                               columns=onehotencoder.get_feature_names_out(['Country']))

# Concatenate the OneHotEncoded columns with the original DataFrame
df = pd.concat([a4, encoded_country], axis=1)


# Drop the original 'Country' column as it's encoded now
a4.drop('Country', axis=1, inplace=True)

# %%
# --- Part B: Apply Label Encoding on the 'Purchased' column ---

# Create a LabelEncoder instance
labelencoder = LabelEncoder()

# Apply Label Encoding on the 'Purchased' column
a4['Department'] = labelencoder.fit_transform(a4['Department'])

# %%
# Display the modified DataFrame
print("\nDataFrame after encoding:")
print(a4)
# Out:
# DataFrame after encoding:
#       No   First Name Last Name  Gender Start Date  Years  Department Center  \
# 0      1       Ghadir     Hmshw    Male 2018-04-04      2          15   West
# 1      2         Omar    Hishan    Male 2020-05-21      0          15   West
# 2      3        Ailya    Sharaf  Female 2017-09-28      3           8   West
# 3      4         Lwiy     Qbany    Male 2018-08-14      2           9   Main
# 4      5        Ahmad     Bikri    Male 2020-03-11      0           9   Main
# ..   ...          ...       ...     ...        ...    ...         ...    ...
# 684  685         Sari     Hanna    Male 2020-05-26      0          11  South
# 685  686      Eubayda      Kayd    Male 2020-06-03      0           4  North
# 686  687       Khalil    Alkalu    Male 2017-07-11      3           4  North
# 687  688      Muhamad    Shrbjy    Male 2018-05-30      2           1  North
# 688  689  Abd Albasit   AlAhmar    Male 2020-08-05      0           7  North
#
# ...

# %% [markdown]
# #	Write a program in python to perform following task :
#  Standardizing Data (transform them into a standard Gaussian distribution with a mean of 0 and a standard deviation of 1) (Use winequality-red.csv)

# %%
from sklearn.preprocessing import StandardScaler

# Selecting only the numerical columns for standardization
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Initialize the StandardScaler
scaler = StandardScaler()

# Apply the scaler to the numerical columns
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Display the first few rows of the standardized data
df.head()
# Out:
#          No First Name Last Name  Gender Start Date     Years  \
# 0 -1.729539     Ghadir     Hmshw    Male 2018-04-04  0.440256
# 1 -1.724511       Omar    Hishan    Male 2020-05-21 -1.240277
# 2 -1.719483      Ailya    Sharaf  Female 2017-09-28  1.280522
# 3 -1.714456       Lwiy     Qbany    Male 2018-08-14  0.440256
# 4 -1.709428      Ahmad     Bikri    Male 2020-03-11 -1.240277
#
#            Department               Country Center  Monthly Salary  \
# 0     Quality Control                 Egypt   West       -0.666289
# 1     Quality Control          Saudi Arabia   West        1.545488
# 2  Major Mfg Projects          Saudi Arabia   West        0.573985
# 3       Manufacturing  United Arab Emirates   Main       -0.314922
# 4       Manufacturing                 Egypt   Main       -1.439821
#
#    Annual Salary  Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours  \
# 0      -0.666289 -0.434614    -0.277781      -0.461002        6.594278
# ...

# %% [markdown]
# # Write a python program to Display column-wise mean, and median for SOCRHeightWeight dataset.

# %%
xx = pd.read_csv('/content/SOCR-HeightWeight.csv')
xx.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
H_mean = xx['Height(Inches)'].mean()
print(f'Height (Inches) Mean : {H_mean}')
# Out:
# Height (Inches) Mean : 67.99311359679999

# %%
W_mean = xx['Weight(Pounds)'].mean()
print(f'Weight(Pounds) Mean : {W_mean}')
# Out:
# Weight(Pounds) Mean : 127.07942116080001

# %% [markdown]
# # Write a python program to compute sum of Manhattan distance between all pairs of points.

# %% [markdown]
# # Write a Python program to create data frame containing column name, salary, department add 10 rows with some missing and duplicate values to the data frame. Also drop all null and empty values. Print the modified data frame.

# %%
# Create a DataFrame with some missing and duplicate values
data =   {'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Ivy', 'John'],
    'salary': [70000, 85000, np.nan, 75000, 95000, 70000, np.nan, 80000, 85000, 90000],
    'department': ['HR', 'IT', 'Finance', 'IT', np.nan, 'HR', 'Finance', np.nan, 'IT', 'Marketing']}

df = pd.DataFrame(data)
print('---------------------ORIGINAL DATAFRAME--------------------')
print(df)
# Out:
# ---------------------ORIGINAL DATAFRAME--------------------
#       name   salary department
# 0    Alice  70000.0         HR
# 1      Bob  85000.0         IT
# 2  Charlie      NaN    Finance
# 3    David  75000.0         IT
# 4      Eve  95000.0        NaN
# 5    Frank  70000.0         HR
# 6    Grace      NaN    Finance
# 7   Hannah  80000.0        NaN
# 8      Ivy  85000.0         IT
# 9     John  90000.0  Marketing

# %%
# Drop rows with null and missing values
data_cleaned = df.dropna()

# Drop duplicate rows based on all columns
df_cleaned = data_cleaned.drop_duplicates()


# Print the cleaned DataFrame
print("\nModified DataFrame after dropping nulls and duplicates:")
print(df_cleaned)
# Out:
# Modified DataFrame after dropping nulls and duplicates:
#     name   salary department
# 0  Alice  70000.0         HR
# 1    Bob  85000.0         IT
# 3  David  75000.0         IT
# 5  Frank  70000.0         HR
# 8    Ivy  85000.0         IT
# 9   John  90000.0  Marketing

# %% [markdown]
# #Write a Python NumPy program to compute the weighted average along the specified axis of a given flattened array.

# %%
import numpy as np

def weighted_average(array, weights):
    """
    Compute the weighted average of a 1D array using the provided weights.

    Parameters:
    array (numpy.ndarray): The flattened 1D array of values.
    weights (numpy.ndarray): The weights for each value in the array.

    Returns:
    float: The weighted average of the array.
    """
    # Ensure the array and weights have the same shape
    if array.shape != weights.shape:
        raise ValueError("Array and weights must have the same shape.")

    # Compute the weighted average
    weighted_sum = np.sum(array * weights)
    sum_of_weights = np.sum(weights)

    if sum_of_weights == 0:
        raise ValueError("Sum of weights must not be zero.")

    return weighted_sum / sum_of_weights

# Example usage
values = np.array([10, 20, 30, 40, 50])
weights = np.array([1, 2, 3, 4, 5])

# Compute weighted average
result = weighted_average(values, weights)
print("Weighted Average:", result)
# Out:
# Weighted Average: 36.666666666666664

# %% [markdown]
# # Write a python program to create two lists, one representing subject names and the other representing marks obtained in those subjects. Display the data in a pie chart and bar chart

# %%
# Define the data
subjects = ['Math', 'English', 'Science', 'History', 'Art']
marks = [85, 90, 78, 88, 92]

# %%
# Create a pie chart
plt.figure(figsize = (10,5))

# Pie chart
plt.subplot(1, 2, 1)
plt.pie(marks, labels=subjects, autopct='%1.1f%%', startangle=140)
plt.title('Marks Distribution by Subject')
# Out:
# Text(0.5, 1.0, 'Marks Distribution by Subject')

# %%
# Bar chart
plt.subplot(1, 2, 2)
plt.bar(subjects, marks, color='skyblue')
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.title('Marks Obtained in Subjects')
# Out:
# Text(0.5, 1.0, 'Marks Obtained in Subjects')
